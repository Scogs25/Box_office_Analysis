# %%
import pandas as pd

df = pd.read_csv("Box_Office_Mojo_Domestic_Box_Office_Chart.csv")

# %%
df
# Out:
#       Unnamed: 0                                   Title       Gross  \
# 0              0    The Woman in Black 2: Angel of Death  26501323.0
# 1              1              The Search for General Tso     54275.0
# 2              2            The Taking of Tiger Mountain    228984.0
# 3              3                           Li'l Quinquin      7192.0
# 4              4                           Trace Amounts     80735.0
# ...          ...                                     ...         ...
# 4026        4026                       The Tax Collector    430423.0
# 4027        4027                               Peninsula    118647.0
# 4028        4028                           Made in Italy     73332.0
# 4029        4029  The SpongeBob Movie: Sponge On The Run    900000.0
# 4030        4030                                 Sputnik     12000.0
#
#       Max_Theaters  Opening_Weekend_Theaters  Opening_Weekend_Gross  \
# 0             2602                      2602             15027415.0
# ...
